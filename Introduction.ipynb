# %% [markdown]
# # Introduction au traitement des images
#
# Ce premier notebook permet de s'initier au chargement, la manipulation et la visualisation des images. Dans un premier temps, une image (rétine, en couleur) est chargée. Son contenu est vérifié, l'image est affichée. Puis l'image est transformée en niveaux de gris  suivant plusieurs méthodes simples.
#
# ## Objectifs
#
# Après ce premier notebook, vous saurez:
# * Charger et visualiser une image.
# * Extraire un canal d'une image couleur.
# * Transformer l'image en noir et blanc.

# %%
# chargement des modules python
import imageio
import matplotlib.pyplot as plt
import numpy as np
from skimage import data

# %% [markdown]
# # Manipulation d'une image en couleurs
#
# Une image couleur est représentée en mémoire par un tableau de nombres à 3 dimensions. Nous allons tester le chargement d'une image de fond d'oeil pour la stocker dans la variable appelée ``retine``. Par la suite, nous allons vérifier les dimensions de cette variable et afficher chaque canal séparément.
#
# Cette image a été fournie par le laboratoire BiiGC de l'université Jean Monnet de Saint-Etienne.

# %%
retine = imageio.imread("retine.png")
plt.imshow(retine)
plt.show()

# %%
# L'image contient 911 par 922 pixels, chaque pixel étant représenté par 3 informations: Rouge, Vert, Bleu, 
# à la manière de l'oeil humain
print(retine.shape)
print(retine.dtype)
# Out:
# (911, 922, 3)
# uint8

# %% [markdown]
# ## 1. Affichage séparé des 3 canaux de couleurs
#
# Les 3 informations composant les couleurs de l'image sont affichées séparément. Attention, la notion de couleur dans ce contexte n'a pas de sens, c'est pourquoi seules des intensités (en niveaux de gris) sont représentées.
#
# On peut remarquer que:
# *  le canal vert présente le meilleur contraste
# *  le canal vert présente la meilleure netteté

# %%
R = retine[:,:,0]
V = retine[:,:,1]
B = retine[:,:,2]

plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.imshow(R, cmap=plt.cm.gray)
plt.title('Canal Rouge')
plt.subplot(132)
plt.imshow(V, cmap=plt.cm.gray)
plt.title('Canal Vert')
plt.subplot(133)
plt.imshow(B, cmap=plt.cm.gray)
plt.title('Canal Bleu')
plt.show()

# %% [markdown]
# ## 2. Transformer une image couleur en image noir et blanc
#
# La photographie suivante a été réalisée par Romaric Juvanon.
#
# <div>
# <img src="boret.jpg" width="500"/>
# </div>
# Nous allons ensemble la transformer en photographie noir et blanc.
#
# 1. De la même manière que pour la rétine, prendre le canal vert de l'image.

# %%
P = imageio.imread('boret.jpg')
V = P[:,:,1]
plt.imshow(V, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# 2. Il existe beaucoup d'autres manières de transformer son image en noir et blanc. Par exemple, prenons la moyenne des 3 canaux:
#
# $$G = \frac{R+V+B}{3}$$
#
# Ce résultat vous semble-t-il meilleur?

# %%
# Attention, il faut manipuler des variables flottantes, sinon le calcul 'dépasse' des bornes
P = P.astype(np.float)
V = P[:,:,1]
R = P[:,:,0]
B = P[:,:,2]
G = (R+V+B)/3
plt.imshow(G, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# 3. Une autre formule est donnée par la formule de mixage des canaux, donnant la luminance:
# $$L=0.2126\times R + 0.7152\times V+0.0772\times B$$
#
# Notez que la somme des coefficients vaut 1.

# %%
L = 0.2126*R+0.7152*V+0.0772*B
plt.imshow(G, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# # 3. Conclusion
#
# La transformation d'une image en n&b est relativement simple. Si l'on n'a que peu de temps, il est facile de ne conserver que le canal vert. Si l'on veut accentuer certains éléments de la scène, il est possible de jouer sur les coefficients du mixage des canaux
